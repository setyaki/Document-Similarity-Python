# %% [markdown]
# # Dependecies library needed for preprocessing

# %%
import os, glob, tika, re, string, io
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from tika import parser

# %% [markdown]
# # Create Sastrawi function, *stopwords and stemming*

# %%
# stopword sastrawi
stopwords_factory = StopWordRemoverFactory()
stopwords = stopwords_factory.create_stop_word_remover()
#additional stopwords
more_stopword = ['undang', 'pasal', 'ayat', 'microsoft', 'word', 'www', 'bphn', 'go', 'id', 'bphngoid', 'wwwbphngoid']
data = stopwords_factory.get_stop_words() + more_stopword #merge data from more_stopwords
dictionary = ArrayDictionary(data)
additional_stopwords = StopWordRemover(dictionary)
stopwords = stopwords_factory.create_stop_word_remover() #create stopwords from default option sastrawi

# create stemmer from StemmerFactory
stemmer_factory = StemmerFactory()
stemmer = stemmer_factory.create_stemmer()

# %% [markdown]
# # Create function `text_preprocessing` for cleaning document

# %%
# define text_preprocessing function
def text_preprocessing (text):
    # checking if dataset is a full picture with no string attach, if it is will skip and return it with 0
    if text is None: 
        return 0
    else:
        text = text.lower() #case folding
        text = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", text) #remove link URL with https
        text = text.translate(str.maketrans('', '', string.punctuation)) # Remove common punctuations
        text = text.strip() # Remove leading and trailing whitespaces
        text = additional_stopwords.remove(text) #remove custom additional stopwords
        text = stemmer.stem(text) #stemming with sastrawi
        text = stopwords.remove(text) # remove stopwords from sastrawi
        text = re.sub(r'[^A-Za-z]+', ' ', text) #remove exlude alphabet (including whitespace)
        text = re.sub(r'\b\w{1,3}\b', '', text) #remove string <3 character
        text = re.sub(r'[^A-Za-z]+', ' ', text) #remove exlude alphabet (including whitespace)
        #text = re.split("\s", text) # (tokenize) split every whitespace occure ['char', 'char']
        return text

# %% [markdown]
# # Create function for extracting preprocessed text into `.txt` file
#
# ### `.txt` file will make the computation for document similarities more convenient

# %%
# define filename processed file .txt
def process_filename (raw_filename, content): #process_filename(judul.txt, isi_content)
    rm_pdfname = re.sub(".pdf", '', raw_filename) #remove .pdf and replace it with empty string
    processed_file = open(rm_pdfname + '_processed.txt', 'w')
    processed_file_content = repr(content) #repr: fill/append the content txt document
    processed_file.write(processed_file_content) # write the content on processed file
    processed_file.close() #close txt document

# %% [markdown]
# # Cleaning document process and exporting it into `.txt` files

# %%
# looping sebanyak jumlah dokumen untuk ekstrak preprocessing data
def main_preprocessing_data (input_path):
    for input_file in glob.glob(os.path.join(input_path, '*.pdf')):
        print(input_file) # checking
        print('***********\nprocessing... please wait\n---------')
        parserPDF = parser.from_file(input_file)
        # extracting content
        raw = parserPDF['content'] # parsing document from pdf files with tika parser
        raw = text_preprocessing(raw) # cleaning content for raw content from parserPDF 
        process_filename(input_file,raw) # extracting title,content from raw to .txt
        print(raw)
    print('\n============================ \n')

# %% [markdown]
# # Path directory contained input file (`.pdf`) *dataset* and *query*

# %%
# input path directory
dataset_path = 'D:\\Kuliah\\dataset'
query_path = 'D:\\Kuliah\\query'

# %% [markdown]
# # Query preprocessing

# %%
#preprocessing query
main_preprocessing_data(query_path)
# Out:
# D:\Kuliah\query\PERATURAN REKTOR UNIVERSITAS LAMPUNG edit.pdf
# ***********
# processing... please wait
# ---------
# 2021-11-23 17:07:11,286 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# atur rektor universitas lampung nomor tahun pedoman barangjasa badan layan umum universitas lampung rahmat tuhan maha rektor universitas lampung timbang rangka penuh atur presiden nomor tahun barangjasa perintah juncto atur presiden tahun ubah atas atur presiden nomor tahun barangjasa perintah universitas lampung badan layan umum perlu susun atur barangjasa dasar timbang bagaimana maksud huruf perlu tetap atur rektor pedoman barangjasa badan layan umum universitas lampung ingat undangundang nomor tahun uang negara lembar negara tahun nomor tambah lembar negara nomor undangundang nomor tahun bendahara negara lembar negara tahun nomor tambah lembar negara nomor undangundang nomor tahun didik tinggi lembar negara republik indonesia tahun nomor tambah lembar negara republik indonesia nomor atur perintah nomor tahun kelola uang badan layan umum bagaimana ubah atur perintah nomor tahun ubah atas atur perintah nomor tahun kelola uang badan layan umum lembar negara tahun nomor tambah lembar negara nomor atur perintah nomor tahun selenggara didik tinggi kelola guru tinggi lembar negara tahun nomor tambah lembar negara nomor atur presiden nomor tahun barangjasa perintah juncto atur presiden tahun ubah atas atur presiden nomor tahun barangjasa perintah atur menteri uang nomor tahun pedoman kelola badan layan umum salin atur menteri didik budaya nomor tahun organisasi tata kerja universitas lampung atur menteri riset teknologi didik tinggi nomor tahun statuta universitas lampung putus tetap atur rektor pedoman barangjasa badan layan umum universitas lampung putus tetap atur rektor pedoman barangjasa badan layan umum universitas lampung umum pertama pasal atur maksud badan layan umum lanjut sebut instansi lingkung perintah bentuk beri layan masyarakat sedia barang danatau jasa jual utama cari untung laku giat dasar prinsip efisiensi produktivitas universitas lampung lanjut singkat unila guru tinggi selenggara program didik akademik vokasi jumlah disiplin ilmu tahu teknologi seni olahraga penuh syarat selenggara didik profesi sesuai atur perundangundangan penanggungjawab jabat milik wenang laku barangjasa kuasa anggar lanjut singkat jabat kuasa anggar laksana wenang tanggungjawab anggar unila jabat buat komitmen lanjut sebut jabat beri wenang pimpin unila ambil putus danatau laku tindak akibat keluar anggar unila jabat beli personil angkat pimpin unila laksana langsung danatau tunjuk langsung sesuai wenang pokja pilih kelompok kerja tetap pimpin unila laksana barangjasa lalu metode quatation tender tunjuk langsung unit barang jasa lanjut sebut upbj unila unit kerja jadi pusat unggul barangjasa universitas lampung rencana unit upbj unila laksana susun rencana sama fakultasunit kerja liput identifikasi butuh tetap barangjasa cara jadwal anggar barangjasa sama susun selenggara swakelola swakelola bentuk menyelenggaran giat swakelola emarketplace barangjasa warung elektronik unila sedia penuh butuh barangjasa pimpin badan layan umum universitas lampung lanjut sebut pimpin unila rektor rektor rektor unila satu awas internal auditor internal suatu guru tinggi tugas fungsi senantiasa evaluasi hasil kerja uang guru tinggi awas tiap bijak manajemen lapor hasil evaluasi awas sebut pimpin user unit kerja butuh hasil barangjasapekerjaan konstruksi rencana strategis bisnis lanjut sebut renstra bisnis dokumen rencana kembang unila jangka waktu lima tahun rencana bisnis anggar tahun lanjut sebut dokumen rencana bisnis anggar program giat target kerja anggar unila susun laksana jangka waktu satu tahun barangjasa giat barang jasa danatau kerja konstruksi civil works proses mulai identifikasi butuh serah terima hasil kerja barang jenis bentuk benda berwujudtidak wujud gerak danatau gerak digunakandipakaidimanfaatkan dagang formatted highlight formatted highlight commented unila perlu buat market place jasa konsultansi jasa utama mampu olah pikir brainware suatu tata kelola kenal luas dunia usaha selesai suatu kerja jasa nonkonsultansi jasa alat metodologi kh ...
#
# ============================

# %% [markdown]
# # Dataset preprocessing

# %%
#preprocessing dataset
main_preprocessing_data(dataset_path)
# Out:
# D:\Kuliah\dataset\PERTOR PBJ UNNES REV 16_11.pdf
# ***********
# processing... please wait
# ---------
#  atur rektor universitas negeri semarang nomor tahun pedoman barangjasa badan layan umum universitas negeri semarang rahmat tuhan maha rektor universitas negeri semarang timbang rangka penuh atur presiden nomor tahun barangjasa perintah universitas negeri semarang badan layan umum perlu susun atur barangjasa dasar timbang bagaimana maksud huruf perlu tetap atur rektor pedoman barangjasa badan layan umum universitas negeri semarang ingat undangundang nomor tahun uang negara lembar negara tahun nomor tambah lembar negara nomor undangundang nomor tahun bendahara negara lembar negara tahun nomor tambah lembar negara nomor undangundang nomor tahun didik tinggi lembar negara republik indonesia tahun nomor tambah lembar negara republik indonesia nomor atur perintah nomor tahun kelola uang badan layan umum bagaimana ubah atur perintah nomor tahun ubah atas atur perintah nomor tahun kelola uang badan layan umum lembar negara tahun nomor tambah lembar negara nomor salin atur perintah nomor tahun selenggara didik tinggi kelola guru tinggi lembar negara tahun nomor tambah lembar negara nomor atur presiden nomor tahun barangjasa perintah lembar negara tahun nomor atur menteri uang nomor tahun wenang barangjasa badan layan umum atur menteri riset teknologi didik tinggi nomor tahun organisasi tata kerja universitas negeri semarang berita negara tahun nomor atur menteri riset teknologi didik tinggi nomor tahun statuta universitas negeri semarang berita negara tahun nomor putus menteri riset teknologi didik tinggi nomor henti angkat prof fathur rokhman mhum rektor universitas negeri semarang periode putus tetap atur rektor pedoman barangjasa badan layan umum universitas negeri semarang umum pertama pasal atur maksud badan layan umum lanjut sebut instansi lingkung perintah bentuk beri layan masyarakat sedia barang danatau jasa jual utama cari untung laku giat dasar prinsip efisiensi produktivitas universitas negeri semarang lanjut singkat unnes guru tinggi selenggara program didik akademik vokasi jumlah disiplin ilmu tahu teknologi seni olahraga penuh syarat selenggara didik profesi sesuai atur undang undang penanggungjawab jabat milik wenang laku barangjasa kuasa anggar lanjut singkat jabat kuasa anggar laksana wenang tanggungjawab anggar unnes jabat buat komitmen lanjut sebut jabat beri wenang pimpin unnes ambil putus danatau laku tindak akibat keluar anggar unnes jabat beli personil angkat pimpin unnes laksana langsung danatau tunjuk langsung sesuai wenang pokja pilih kelompok kerja tetap pimpin unnes laksana barangjasa lalu metode quatation tender tunjuk langsung badan barang jasa lanjut sebut bpbj unnes unit kerja jadi pusat unggul barangjasa universitas negeri semarang rencana unit bpbj unnes laksana susun rencana sama fakultasunit kerja liput identifikasi butuh tetap barangjasa cara jadwal anggar barangjasa sama susun selenggara swakelola swakelola bentuk menyelenggaran giat swakelola emarketplace barangjasa warung elektronik unnes sedia penuh butuh barangjasa pimpin badan layan umum universitas negeri semarang lanjut sebut pimpin unnes rektor rektor rektor unnes satu awas internal auditor internal suatu guru tinggi tugas fungsi senantiasa evaluasi hasil kerja uang guru tinggi awas tiap bijak manajemen lapor hasil evaluasi awas sebut pimpin user unit kerja butuh hasil barangjasapekerjaan konstruksi rencana strategis bisnis lanjut sebut renstra bisnis dokumen rencana kembang unnes jangka waktu lima tahun rencana bisnis anggar tahun lanjut sebut dokumen rencana bisnis anggar program giat target kerja anggar unnes susun laksana jangka waktu satu tahun barangjasa giat barang jasa danatau kerja konstruksi civil works proses mulai identifikasi butuh serah terima hasil kerja barang jenis bentuk benda berwujudtidak wujud gerak danatau gerak digunakandipakaidimanfaatkan dagang formatted highlight formatted highlight jasa konsultansi jasa utama mampu olah pikir brainware suatu tata kelola kenal luas dunia usaha selesai suatu kerja jasa nonkonsulta ...
#
# ============================
